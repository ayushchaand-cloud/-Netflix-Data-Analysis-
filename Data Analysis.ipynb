# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/netflix_titles.csv

# %% [markdown]
# # Hi, I’m Ayush Singh, a B.Tech Computer Science student (Batch 2024–2028) from AKTU, Lucknow, Uttar Pradesh.
#
# This notebook is part of my mini project, where I am analyzing a Netflix dataset to explore various insights such as:
# ![download.jpg](attachment:ede2ecdb-16b4-456e-8165-92968f02fc4f.jpg)
#
#
#
# Trends in Netflix movies and TV shows
#
# Distribution of content across genres, countries, and release years
#
# Popularity patterns and other interesting findings
#
# The goal of this project is to apply data analysis and visualization techniques to understand how Netflix’s content has evolved over time.
#
# This notebook combines Python, Pandas, Matplotlib, and Seaborn to clean, process, and visualize the dataset, making the analysis more meaningful and easy to interpret.

# %%
import pandas as pd 

import matplotlib.pyplot as pit

# %%
df=pd.read_csv("/kaggle/input/netflix_titles.csv")
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %%
df.describe()
# Out:
#        release_year
# count   8807.000000
# mean    2014.180198
# std        8.819312
# min     1925.000000
# 25%     2013.000000
# 50%     2017.000000
# 75%     2019.000000
# max     2021.000000

# %% [markdown]
# # Director with Most Releases on Netflix

# %%
m=df['director'].value_counts()
p=m.head(1).sort_values()
p
# Out:
# director
# Rajiv Chilaka    19
# Name: count, dtype: int64

# %% [markdown]
# ![rajiv.jpg](attachment:407d358a-1e20-422d-8689-d5cda8e4398a.jpg)

# %% [markdown]
# **RAJIV** **CHILAKA**

# %% [markdown]
# # Director with the least Releases on Netflix

# %%
m=df['director'].value_counts()
p=m.tail(1).sort_values()
p
# Out:
# director
# Mozez Singh    1
# Name: count, dtype: int64

# %% [markdown]
# ![OIP.jpg](attachment:2cbbe362-0282-4fc3-9e15-e1e80d086bcd.jpg)

# %% [markdown]
# **Mozez** **Singh**

# %% [markdown]
# # THE LIST OF TOP 3 COUNTRY WHICH RELAIESD MORE MOVIES ON NETFLIX

# %%
M=df['country'].value_counts()
M.head(3).plot(kind='bar')
# Out:
# <Axes: xlabel='country'>

# %% [markdown]
# **1.United States **
# ![map-163635_1280.webp](attachment:3183af5b-0f9e-40c2-aa7c-716cf55ecc31.webp)

# %% [markdown]
# 2.India

# %% [markdown]
# ![1000_F_82363980_pDVqnlc3bORUsazhDzHuFvBUq3fZbQkH.jpg](attachment:b0867167-34e8-4328-94f5-635a4b930f06.jpg)

# %% [markdown]
# 3.United kindom
# ![united-kingdom-waving-flag-realistic-transparent-background-free-png.webp](attachment:fc69c6f1-00a8-410f-b827-d48c3404bc6d.webp)

# %% [markdown]
# # Country with Least Movies Releases on Netflix

# %%
M=df['country'].value_counts()
M.tail(1)
# Out:
# country
# United Arab Emirates, Jordan    1
# Name: count, dtype: int64

# %% [markdown]
# ![OIP.jpg](attachment:b6ab8c24-1f2b-4887-a5c4-d2859b88e1ef.jpg)

# %% [markdown]
# # Top 3 Years with Highest moives Releases

# %%
y=df['release_year'].value_counts().head(3)
y.plot(kind="bar")
# Out:
# <Axes: xlabel='release_year'>

# %% [markdown]
# **The Years are**
# 1. 2018
# 2. 2017
# 3. 2019

# %% [markdown]
# # TOP 3 HIGHER LISTED MOIVES-CATEGORY ON NETFLIX

# %%
df['listed_in'].value_counts().head(3).plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# # TOP 3 LESS LISTED MOIVES-CATEGORY ON NETFLIX

# %%
df['listed_in'].value_counts().tail(3).plot(kind='barh')
# Out:
# <Axes: ylabel='listed_in'>

# %% [markdown]
# # THE CHART OF NETFLIX CONTENT TYPE

# %%
df['type'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# # TOP 3 Years with Most Movie release

# %%
df['release_year'].value_counts().head(3).plot(kind="pie")
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# By above anlayise found thats:
# * In 2018 there are 1147 movies realsed
# * In 2017 there are 1032
# * in 2019 there are 1032

# %% [markdown]
# # In Which Year were the least number of the movies released

# %%
df['release_year'].value_counts().tail(5).plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# # Which  type of movie ratings are released the most on Netflix ?

# %%
df['rating'].value_counts().plot(kind='barh')
# Out:
# <Axes: ylabel='rating'>

# %% [markdown]
# **By above Analyis:**
# 1. TV-MA is the Most
# 2. 66 min is the Least

# %% [markdown]
# # TOP 3 Counrty Who Produce TV-MA Rate On NETFLIX

# %%
df[df["rating"]=="TV-MA"][["rating","country"]].value_counts().head(3).plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# * By the above Anlayis I found that cross the Netflix (USA,UK,INDIA) Produce TV-MA rate Most

# %% [markdown]
# # Which country releases the least number of TV-MA rated movies on Netflix

# %%
df[df["rating"]=="TV-MA"][["rating","country"]].value_counts().tail(1)
# Out:
# rating  country
# TV-MA   West Germany    1
# Name: count, dtype: int64

# %% [markdown]
# **West Germany which releases least TV-MA rated movies**

# %%
df['rating'].value_counts()
# Out:
# rating
# TV-MA       3207
# TV-14       2160
# TV-PG        863
# R            799
# PG-13        490
# TV-Y7        334
# TV-Y         307
# PG           287
# TV-G         220
# NR            80
# G             41
# TV-Y7-FV       6
# NC-17          3
# UR             3
# 74 min         1
# 84 min         1
# 66 min         1
# Name: count, dtype: int64

# %% [markdown]
# # TV-14

# %%
df[df["rating"]=="TV-14"][["rating","country"]].value_counts().head(3).plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
df[df["rating"]=="TV-14"][["rating","country"]].value_counts().tail(1)
# Out:
# rating  country
# TV-14   Kenya      1
# Name: count, dtype: int64

# %% [markdown]
# # Countries where dramas are popular.

# %%
m=df[df["listed_in"]=="Dramas"]["country"].value_counts().sort_values(ascending=False)
m.head(3).plot(kind="pie")
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# After analyzing the dataset, it was observed that the United States has the highest number of dramas available on Netflix. Germany and the United Kingdom also contribute significantly to the drama content library.

# %% [markdown]
# # 👉 “Which country has the least drama?”

# %%
m=df[df["listed_in"]=="Dramas"]["country"].value_counts().sort_values(ascending=True)
m.head().plot(kind="bar")
# Out:
# <Axes: xlabel='country'>

# %% [markdown]
# #                         SEASONS DEATILS

# %%
df[df["duration"]>"1 Season"]
# Out:
#      show_id     type                             title  \
# 0         s1    Movie              Dick Johnson Is Dead
# 1         s2  TV Show                     Blood & Water
# 4         s5  TV Show                      Kota Factory
# 6         s7    Movie  My Little Pony: A New Generation
# 7         s8    Movie                           Sankofa
# ...      ...      ...                               ...
# 8802   s8803    Movie                            Zodiac
# 8803   s8804  TV Show                       Zombie Dumb
# 8804   s8805    Movie                        Zombieland
# 8805   s8806    Movie                              Zoom
# 8806   s8807    Movie                            Zubaan
#
#                            director  \
# 0                   Kirsten Johnson
# 1                               NaN
# 4                               NaN
# 6     Robert Cullen, José Luis Ucha
# 7                      Haile Gerima
# ...                             ...
# ...

# %% [markdown]
# “After the analysis, it was found that there are **7011** or movies with more than Season 1.”

# %%
df[df["duration"]>"2 Seasons"]
# Out:
#      show_id     type                             title  \
# 0         s1    Movie              Dick Johnson Is Dead
# 6         s7    Movie  My Little Pony: A New Generation
# 8         s9  TV Show     The Great British Baking Show
# 13       s14    Movie  Confessions of an Invisible Girl
# 15       s16  TV Show                 Dear White People
# ...      ...      ...                               ...
# 8794   s8795    Movie                            اشتباك
# 8797   s8798  TV Show                         Zak Storm
# 8801   s8802    Movie                           Zinzana
# 8804   s8805    Movie                        Zombieland
# 8805   s8806    Movie                              Zoom
#
#                            director  \
# 0                   Kirsten Johnson
# 6     Robert Cullen, José Luis Ucha
# 8                   Andy Devonshire
# 13                    Bruno Garotti
# 15                              NaN
# ...                             ...
# ...

# %% [markdown]
# “After the analysis, it was found that there are **3645 Dramas** or movies with more than Season 2.”

# %%
df[df["duration"]>"3 Seasons"]
# Out:
#      show_id     type                             title  \
# 0         s1    Movie              Dick Johnson Is Dead
# 6         s7    Movie  My Little Pony: A New Generation
# 8         s9  TV Show     The Great British Baking Show
# 13       s14    Movie  Confessions of an Invisible Girl
# 15       s16  TV Show                 Dear White People
# ...      ...      ...                               ...
# 8793   s8794    Movie              Yours, Mine and Ours
# 8794   s8795    Movie                            اشتباك
# 8801   s8802    Movie                           Zinzana
# 8804   s8805    Movie                        Zombieland
# 8805   s8806    Movie                              Zoom
#
#                            director  \
# 0                   Kirsten Johnson
# 6     Robert Cullen, José Luis Ucha
# 8                   Andy Devonshire
# 13                    Bruno Garotti
# 15                              NaN
# ...                             ...
# ...

# %% [markdown]
# “After the analysis, it was found that there are **3329dramas** or movies with more than Season 2.”

# %%
df[df["duration"]>"4 Seasons"]
# Out:
#      show_id     type                                              title  \
# 0         s1    Movie                               Dick Johnson Is Dead
# 6         s7    Movie                   My Little Pony: A New Generation
# 8         s9  TV Show                      The Great British Baking Show
# 13       s14    Movie                   Confessions of an Invisible Girl
# 16       s17    Movie  Europe's Most Dangerous Man: Otto Skorzeny in ...
# ...      ...      ...                                                ...
# 8793   s8794    Movie                               Yours, Mine and Ours
# 8794   s8795    Movie                                             اشتباك
# 8801   s8802    Movie                                            Zinzana
# 8804   s8805    Movie                                         Zombieland
# 8805   s8806    Movie                                               Zoom
#
#                                            director  \
# ...

# %% [markdown]
# “After the analysis, it was found that there are **3186 Dramas** or movies with more than Season 2.”

# %%
df[df["duration"]>"5 Seasons"]
# Out:
#      show_id     type                                              title  \
# 0         s1    Movie                               Dick Johnson Is Dead
# 6         s7    Movie                   My Little Pony: A New Generation
# 8         s9  TV Show                      The Great British Baking Show
# 13       s14    Movie                   Confessions of an Invisible Girl
# 16       s17    Movie  Europe's Most Dangerous Man: Otto Skorzeny in ...
# ...      ...      ...                                                ...
# 8793   s8794    Movie                               Yours, Mine and Ours
# 8794   s8795    Movie                                             اشتباك
# 8801   s8802    Movie                                            Zinzana
# 8804   s8805    Movie                                         Zombieland
# 8805   s8806    Movie                                               Zoom
#
#                                            director  \
# ...

# %% [markdown]
# “After the analysis, it was found that there are **3014dramas** or movies with more than Season 5.”

# %% [markdown]
# 📌 **Conclusion**
#
# ✨ This notebook marks the completion of my current analysis on the Netflix Dataset.
# Throughout this exploration, I have tried to uncover meaningful patterns, trends, and insights that help us better understand the data.
#
# 🔍 Data analysis is never truly “finished” — it’s an iterative process. New ideas, features, and approaches will always emerge with time. That’s why I’ll keep this project open for future updates and improvements.
#
# 🚀 For now, this is where I’ll pause my analysis.
# I’ll continue adding more advanced techniques, visualizations, and deeper insights whenever fresh thoughts strike.
#
# 💡 Thank you for going through my work! Your feedback and suggestions will help me improve further.
#
# ✍️ **Author: Ayush Singh | 🎓 B.Tech CSE Student, AKTU Lucknow**
